# %%
import pandas as pd

# %%
companies = pd.read_csv(r'C:\Users\bbsbh\Desktop\Python\companies.csv', index_col = 'id')

# %%
companies.head()
# Out:
#                    name     cik            sector   industry_category  \
# id
# 1             Apple Inc  320193    Consumer Goods   Consumer Durables
# 2   American Express Co    4962         Financial  Financial Services
# 3             Boeing Co   12927  Industrial Goods   Aerospace/Defense
# 4       Caterpillar Inc   18230  Industrial Goods       Manufacturing
# 5     Cisco Systems Inc  858877        Technology   Computer Hardware
#
#                            industry_group  employees
# id
# 1                    Electronic Equipment     132000
# 2                         Credit Services      59000
# 3   Aerospace/Defense Products & Services     153027
# 4           Farm & Construction Machinery     104000
# 5      Networking & Communication Devices      74200

# %%
def status_func(column):
    if column<60000:
        return('Low')    
    elif column > 60000 & column <= 100000:
        return('Medium')
    else:
        return('High')
        
companies['status'] = companies['employees'].apply(status_func)

# %%
companies.head()
# Out:
#                    name     cik            sector   industry_category  \
# id
# 1             Apple Inc  320193    Consumer Goods   Consumer Durables
# 2   American Express Co    4962         Financial  Financial Services
# 3             Boeing Co   12927  Industrial Goods   Aerospace/Defense
# 4       Caterpillar Inc   18230  Industrial Goods       Manufacturing
# 5     Cisco Systems Inc  858877        Technology   Computer Hardware
#
#                            industry_group  employees  status
# id
# 1                    Electronic Equipment     132000  Medium
# 2                         Credit Services      59000     Low
# 3   Aerospace/Defense Products & Services     153027  Medium
# 4           Farm & Construction Machinery     104000  Medium
# 5      Networking & Communication Devices      74200  Medium

# %%
securities = pd.read_csv('securities.csv')

# %%
securities_companies = companies.join(securities)
securities_companies.head()
# Out:
#                    name     cik            sector   industry_category  \
# id
# 1             Apple Inc  320193    Consumer Goods   Consumer Durables
# 2   American Express Co    4962         Financial  Financial Services
# 3             Boeing Co   12927  Industrial Goods   Aerospace/Defense
# 4       Caterpillar Inc   18230  Industrial Goods       Manufacturing
# 5     Cisco Systems Inc  858877        Technology   Computer Hardware
#
#                            industry_group  employees  status   id ticker  \
# id
# 1                    Electronic Equipment     132000  Medium  2.0    AXP
# 2                         Credit Services      59000     Low  3.0     BA
# 3   Aerospace/Defense Products & Services     153027  Medium  4.0    CAT
# 4           Farm & Construction Machinery     104000  Medium  5.0   CSCO
# 5      Networking & Communication Devices      74200  Medium  6.0    CVX
#
#    currency          figi
# id
# 1       USD  BBG000BCR153
# 2       USD  BBG000BCSV38
# 3       USD  BBG000BF0LJ6
# 4       USD  BBG000C3JBN9
# 5       USD  BBG000K4NHJ5

# %%
securities_companies[['name', 'ticker', 'figi']].head()
# Out:
#                    name ticker          figi
# id
# 1             Apple Inc    AXP  BBG000BCR153
# 2   American Express Co     BA  BBG000BCSV38
# 3             Boeing Co    CAT  BBG000BF0LJ6
# 4       Caterpillar Inc   CSCO  BBG000C3JBN9
# 5     Cisco Systems Inc    CVX  BBG000K4NHJ5
